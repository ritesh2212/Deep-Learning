# %% [markdown]
# ### Explore the behaviour of the algorithm both for TWO data sets which are linearly separable and for TWO datasets which are not linearly separable.

# %% [markdown]
# Done in Code

# %% [markdown]
# ### How dependent are the decision boundaries on the initial values of the weights? What do you see for each of the datasets when the initial weights are changed, and why?

# %% [markdown]
# If we initialize all weights with zeros then every hidden unit will get zero independent of the input. So, when all the hidden neurons have zero weights, then they get same gradient and updataion is also same, This only effects scale not direction.  No matter what was the input - if all weights are the same, all units in hidden layer will be the same too.

# %% [markdown]
# ### Compare the final decision boundary in each of the above datasets against the decision boundary obtained using a SVM and logistic regression. What differences do you see and why?

# %% [markdown]
# ### Logistic Regression
# It makes decision boundary based on logistic functions which is mainly probabilistic. While logistic regression the one that minimizes the cross-entropy loss.
# ### SVM
# SVM tries makes decision boundary that reduces the risk of error on the test data. It tries to find a decision boundary that has the same distance from the boundary points of both classes. Decision boundary has maximal margin from both classes. SVM is geometrically motivated rather than statistically.

# %%
from sklearn.datasets.samples_generator import make_blobs
from sklearn.datasets import make_moons
from matplotlib import pyplot as plt
from sklearn.datasets import make_circles
import pandas as pd
import numpy as np
import sklearn

# %% [markdown]
# ## Function to plot graph based on weight ans bais

# %%
def plotGraph(weight,bais,size,df,x):
    

    y = np.multiply((-weight[0]/weight[1]),x)-(bais/weight[1])

    colors = {0:'red', 1:'blue'}
    fig, ax = plt.subplots()
    grouped = df.groupby('label')

    for key, group in grouped:
        group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])

    plt.plot(x,y)
    plt.show()

# %% [markdown]
# # Perceptron algorithm

# %%
def perceptron(df,X,y,weight,bais,size=12,threshold=10):
    x  = np.random.randint(-10,10, size=(size))
    j = 0
    while(j!=threshold):
        j+=1
        for inputs,label in zip(X,y):
            yDash = np.dot(weight,inputs)+bais
            if yDash > 0:
                yDash = 1.0
            else:
                yDash = 0.0
            if yDash!=label:
                weight = weight + inputs*learning_rate*(label)
                bais = bais + learning_rate*(label)
        print("Iteration : ",j," Weights : ",weight, " bais : ",bais)
        plotGraph(weight,bais,size,df,x)
    return weight,bais
def predict(inputs,weight,bais):
    pred = np.dot(weight,inputs)+bais
    if pred <= 0:
        return 0
    else:
        return 1

# %% [markdown]
# # Linear Dataset 1

# %%
# # generate 2d classification dataset
X, y = make_blobs(n_samples=200, centers=2, n_features=2,shuffle=True,random_state=10)
# # scatter plot, dots colored by class value
df_Linear = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
#df.to_csv('./dataset/LinearDataset.csv',sep="\t",index=None)
#df = pd.read_csv('./dataset/LinearDataset.csv',sep='\t')
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
grouped = df_Linear.groupby('label')

for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()

# %%
X = df_Linear.values
y = X[:,-1]
X = X[:,:2]
# y[y==0] = -1
learning_rate = 0.01
weight = np.zeros(2)
weight += 0.001
bais = 0

weight,bais = perceptron(df_Linear,X,y,weight,bais,12)
# i=10
# print(weight,bais)
# print(predict(X[i],weight,bais))
# print(y[i])
# Out:
# Iteration :  1  Weights :  [2.77948285 4.90631135]  bais :  1.0000000000000007
# Iteration :  2  Weights :  [5.5579657  9.81162271]  bais :  2.0000000000000013
# Iteration :  3  Weights :  [ 8.33644854 14.71693406]  bais :  2.99999999999998
# Iteration :  4  Weights :  [11.11493139 19.62224542]  bais :  3.9999999999999587
# Iteration :  5  Weights :  [13.89341424 24.52755677]  bais :  4.999999999999938
# Iteration :  6  Weights :  [16.67189709 29.43286812]  bais :  5.9999999999999165
# Iteration :  7  Weights :  [19.45037994 34.33817948]  bais :  6.999999999999895
# Iteration :  8  Weights :  [22.22886278 39.24349083]  bais :  7.999999999999874
# Iteration :  9  Weights :  [25.00734563 44.14880218]  bais :  8.999999999999853
# Iteration :  10  Weights :  [27.78582848 49.05411354]  bais :  9.999999999999831

# %% [markdown]
# # Linear dataset 2

# %%
# # generate 2d classification dataset
X, y = make_blobs(n_samples=200, centers=2, n_features=2,shuffle=True,random_state=2)
# # scatter plot, dots colored by class value
df_Linear1 = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
#df.to_csv('./dataset/LinearDataset.csv',sep="\t",index=None)
#df = pd.read_csv('./dataset/LinearDataset.csv',sep='\t')
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
grouped = df_Linear1.groupby('label')

for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()

# %%
X = df_Linear1.values
y = X[:,-1]
X = X[:,:2]
learning_rate = 0.001
weight = np.zeros(2)
bais = 0

weight,bais = perceptron(df_Linear1,X,y,weight,bais,10)
# i =19
# print(predict(X[i],weight,bais))
# print(y[i])
# Out:
# Iteration :  1  Weights :  [ 0.10222196 -0.12655455]  bais :  0.10000000000000007
# Iteration :  2  Weights :  [ 0.20444392 -0.25310909]  bais :  0.20000000000000015
# Iteration :  3  Weights :  [ 0.30666589 -0.37966364]  bais :  0.3000000000000002
# Iteration :  4  Weights :  [ 0.40888785 -0.50621818]  bais :  0.4000000000000003
# Iteration :  5  Weights :  [ 0.51110981 -0.63277273]  bais :  0.5000000000000003
# Iteration :  6  Weights :  [ 0.61333177 -0.75932728]  bais :  0.6000000000000004
# Iteration :  7  Weights :  [ 0.71555374 -0.88588182]  bais :  0.7000000000000005
# Iteration :  8  Weights :  [ 0.8177757  -1.01243637]  bais :  0.8000000000000006
# Iteration :  9  Weights :  [ 0.91999766 -1.13899092]  bais :  0.9000000000000007
# Iteration :  10  Weights :  [ 1.02221962 -1.26554546]  bais :  1.0000000000000007

# %% [markdown]
# # Non-Linear dataset
# ## Random dataset

# %%
X,y = sklearn.datasets.samples_generator.make_classification(n_samples=200, n_features=2, n_informative=1,
                        n_redundant=0, n_repeated=0, n_classes=2,
                        n_clusters_per_class=1, weights=None, flip_y=0.01,
                        class_sep=1.0, hypercube=True, shift=0.0, scale=1.0,
                        shuffle=True, random_state=22)
df_Non_Linear = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
# df.to_csv('./dataset/nonLinearDataset.csv',sep="\t",index=None)
#df = pd.read_csv('./dataset/nonLinearDataset.csv',sep='\t')

colors = {0:'red', 1:'blue',2:'green'}
fig, ax = plt.subplots()
grouped = df_Non_Linear.groupby('label')

for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()

# %%
X = df_Non_Linear.values
y = X[:,-1]
X = X[:,:2]
learning_rate = 0.01
weight = np.zeros(2)
bais = 0

weight,bais = perceptron(df_Non_Linear,X,y,weight,bais,8)
# i =19
# print(predict(X[i],weight,bais))
# print(y[i])
# Out:
# Iteration :  1  Weights :  [-0.00378883  0.00666054]  bais :  0.02
# Iteration :  2  Weights :  [-0.00378883  0.00666054]  bais :  0.02
# Iteration :  3  Weights :  [-0.00378883  0.00666054]  bais :  0.02
# Iteration :  4  Weights :  [-0.00378883  0.00666054]  bais :  0.02
# Iteration :  5  Weights :  [-0.00378883  0.00666054]  bais :  0.02
# Iteration :  6  Weights :  [-0.00378883  0.00666054]  bais :  0.02
# Iteration :  7  Weights :  [-0.00378883  0.00666054]  bais :  0.02
# Iteration :  8  Weights :  [-0.00378883  0.00666054]  bais :  0.02
# Iteration :  9  Weights :  [-0.00378883  0.00666054]  bais :  0.02
# Iteration :  10  Weights :  [-0.00378883  0.00666054]  bais :  0.02

# %% [markdown]
# # Moon Dataset

# %%
# generate 2d classification dataset
X, y = make_moons(n_samples=100, noise=0.2)
# scatter plot, dots colored by class value
df_MOON = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
grouped = df_MOON.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()

# %%
X = df_MOON.values
y = X[:,-1]
X = X[:,:2]
learning_rate = 0.01
weight = np.zeros(2)
bais = 0

weight,bais = perceptron(df_MOON,X,y,weight,bais,4)
i =13
print(predict(X[i],weight,bais))
print(y[i])
# Out:
# Iteration :  1  Weights :  [ 0.01079818 -0.00345647]  bais :  0.02
# Iteration :  2  Weights :  [ 0.01079818 -0.00345647]  bais :  0.02
# Iteration :  3  Weights :  [ 0.01079818 -0.00345647]  bais :  0.02
# Iteration :  4  Weights :  [ 0.01079818 -0.00345647]  bais :  0.02
# Iteration :  5  Weights :  [ 0.01079818 -0.00345647]  bais :  0.02
# Iteration :  6  Weights :  [ 0.01079818 -0.00345647]  bais :  0.02
# Iteration :  7  Weights :  [ 0.01079818 -0.00345647]  bais :  0.02
# Iteration :  8  Weights :  [ 0.01079818 -0.00345647]  bais :  0.02
# Iteration :  9  Weights :  [ 0.01079818 -0.00345647]  bais :  0.02
# Iteration :  10  Weights :  [ 0.01079818 -0.00345647]  bais :  0.02
# 1
# 1.0

# %% [markdown]
# # Circle Dataset

# %%
# generate 2d classification dataset
X, y = make_circles(n_samples=100, noise=0.05)
# scatter plot, dots colored by class value
df_Circle = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
grouped = df_Circle.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()

# %%
X = df_Circle.values
y = X[:,-1]
X = X[:,:2]
learning_rate = 0.01
weight = np.zeros(2)
bais = 0

weight,bais = perceptron(df_Circle,X,y,weight,bais,28)
i =13
print(predict(X[i],weight,bais))
print(y[i])
# Out:
# Iteration :  1  Weights :  [-0.0043971  -0.00597756]  bais :  0.01
# Iteration :  2  Weights :  [-0.0043971  -0.00597756]  bais :  0.01
# Iteration :  3  Weights :  [-0.0043971  -0.00597756]  bais :  0.01
# Iteration :  4  Weights :  [-0.0043971  -0.00597756]  bais :  0.01
# Iteration :  5  Weights :  [-0.0043971  -0.00597756]  bais :  0.01
# Iteration :  6  Weights :  [-0.0043971  -0.00597756]  bais :  0.01
# Iteration :  7  Weights :  [-0.0043971  -0.00597756]  bais :  0.01
# Iteration :  8  Weights :  [-0.0043971  -0.00597756]  bais :  0.01
# Iteration :  9  Weights :  [-0.0043971  -0.00597756]  bais :  0.01
# Iteration :  10  Weights :  [-0.0043971  -0.00597756]  bais :  0.01
# 1
# 1.0

# %%
# x = np.random.randint(-1,1, size=(7))

# y = np.multiply(-weight[0]/weight[1],x)-(bais/weight[1])

# colors = {0:'red', 1:'blue'}
# fig, ax = plt.subplots()
# grouped = df_Circle.groupby('label')

# for key, group in grouped:
#     group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])

# plt.plot(x,y)
# plt.show()

# %% [markdown]
# # Part B

# %% [markdown]
# ## Linear Dataset

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions
clf = SVC(C=0.5, kernel='linear')

# %%
#Linear Dataset 1
X = df_Linear.values
y = X[:,-1]
y = y.astype(np.int)
X = X[:,:2]

# %%
clf.fit(X,y)
plot_decision_regions(X, y, clf=clf, legend=2)
plt.title("SVM For Linear dataset1")
plt.show()

# %%
#Linear Dataset 2
X = df_Linear1.values
y = X[:,-1]
y = y.astype(np.int)
X = X[:,:2]

# %%
clf.fit(X,y)
plot_decision_regions(X, y, clf=clf, legend=2)
plt.title("SVM For Linear dataset2")
plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0, solver='lbfgs',
                         multi_class='multinomial')

# %%
#Linear Dataset 1
X = df_Linear.values
y = X[:,-1]
y = y.astype(np.int) 
X = X[:,:2]

# %%
clf.fit(X, y)
plot_decision_regions(X, y, clf=clf, legend=2)
plt.title("Logistic Regression For Linear dataset1")
plt.show()

# %%
#Linear Dataset 2
X = df_Linear1.values
y = X[:,-1]
y = y.astype(np.int) 
X = X[:,:2]

# %%
clf.fit(X, y)
plot_decision_regions(X, y, clf=clf, legend=2)
plt.title("Logistic Regression For Linear dataset2")
plt.show()

# %% [markdown]
# ## Non-Linear Dataset

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
clf = SVC(C=0.5, kernel='linear')

# %%
#Non-Linear Dataset 1
X = df_Non_Linear.values
y = X[:,-1]
y= y.astype(np.int)
X = X[:,:2]

# %%
clf.fit(X, y)
plot_decision_regions(X, y, clf=clf, legend=2)
plt.title("SVM For Non Linear dataset")
plt.show()

# %%
#Non-Linear Moon Dataset 
X = df_MOON.values
y = X[:,-1]
y = y.astype(np.int)
X = X[:,:2]

# %%
clf.fit(X, y)
plot_decision_regions(X, y, clf=clf, legend=2)
plt.title("SVM For Moondataset")
plt.show()

# %%
#Non-Linear Circle Dataset 
X = df_Circle.values
y = X[:,-1]
y = y.astype(np.int)
X = X[:,:2]

# %%
clf.fit(X, y)
plot_decision_regions(X, y, clf=clf, legend=2)
plt.title("SVM For Circle dataset")
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
clf = LogisticRegression(random_state=0, solver='lbfgs',
                         multi_class='multinomial')

# %%
#Non-Linear Dataset 1
X = df_Non_Linear.values
y = X[:,-1]
y = y.astype(np.int) 
X = X[:,:2]

# %%
clf.fit(X, y)
plot_decision_regions(X, y, clf=clf, legend=2)
plt.title("Logistic Regression For Non Linear dataset")
plt.show()

# %%
#Non-Linear Moon Dataset
X = df_MOON.values
y = X[:,-1]
y = y.astype(np.int) 
X = X[:,:2]

# %%
clf.fit(X, y)
plot_decision_regions(X, y, clf=clf, legend=2)
plt.title("Logistic Regression For Moon Dataset")
plt.show()

# %%
#Non-Linear Circle Dataset 
X = df_Circle.values
y = X[:,-1]
y = y.astype(np.int) 
X = X[:,:2]

# %%
clf.fit(X, y)
plot_decision_regions(X, y, clf=clf, legend=2)
plt.title("Logistic Regression For Circle dataset")
plt.show()
