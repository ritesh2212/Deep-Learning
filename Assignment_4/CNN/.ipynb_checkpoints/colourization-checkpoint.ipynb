# %% [markdown]
# # Colab FAQ
#
# For some basic overview and features offered in Colab notebooks, check out: [Overview of Colaboratory Features](https://colab.research.google.com/notebooks/basic_features_overview.ipynb)
#
# You need to use the colab GPU for this assignmentby selecting:
#
# > **Runtime**   →   **Change runtime type**   →   **Hardware Accelerator: GPU**

# %% [markdown]
# # Download CIFAR and Colour dictionary
# It can take up to a couple of minutes to download everything the first time.

# %% [markdown]
# ## Helper code
# You can ignore the restart warning.

# %%
######################################################################
# Setup python environment and change the current working directory
######################################################################
# !pip install torch torchvision
# !pip install Pillow==4.0.0
# %mkdir -p /content/cs6360/a2/
# %cd /content/cs6360/a2

# %%
# adapted from 
# https://github.com/fchollet/keras/blob/master/keras/datasets/cifar10.py

import os
from six.moves.urllib.request import urlretrieve
import tarfile
import numpy as np
import pickle
import sys
from PIL import Image
import imageio

def get_file(fname,
             origin,
             untar=False,
             extract=False,
             archive_format='auto',
             cache_dir='data'):
    datadir = os.path.join(cache_dir)
    if not os.path.exists(datadir):
        os.makedirs(datadir)

    if untar:
        untar_fpath = os.path.join(datadir, fname)
        fpath = untar_fpath + '.tar.gz'
    else:
        fpath = os.path.join(datadir, fname)
    
    #print(fpath)
    if not os.path.exists(fpath):
        print('Downloading data from', origin)

        error_msg = 'URL fetch failure on {}: {} -- {}'
        try:
            try:
                urlretrieve(origin, fpath)
            except URLError as e:
                raise Exception(error_msg.format(origin, e.errno, e.reason))
            except HTTPError as e:
                raise Exception(error_msg.format(origin, e.code, e.msg))
        except (Exception, KeyboardInterrupt) as e:
            if os.path.exists(fpath):
                os.remove(fpath)
            raise

    if untar:
        if not os.path.exists(untar_fpath):
            print('Extracting file.')
            with tarfile.open(fpath) as archive:
                archive.extractall(datadir)
        return untar_fpath

    if extract:
        _extract_archive(fpath, datadir, archive_format)

    return fpath



def load_batch(fpath, label_key='labels'):
    """Internal utility for parsing CIFAR data.
    # Arguments
        fpath: path the file to parse.
        label_key: key for label data in the retrieve
            dictionary.
    # Returns
        A tuple `(data, labels)`.
    """
    f = open(fpath, 'rb')
    if sys.version_info < (3,):
        d = pickle.load(f)
    else:
        d = pickle.load(f, encoding='bytes')
        # decode utf8
        d_decoded = {}
        for k, v in d.items():
            d_decoded[k.decode('utf8')] = v
        d = d_decoded
    f.close()
    data = d['data']
    labels = d[label_key]

    data = data.reshape(data.shape[0], 3, 32, 32)
    return data, labels

def load_cifar10(transpose=False):
    """Loads CIFAR10 dataset.
    # Returns
        Tuple of Numpy arrays: `(x_train, y_train), (x_test, y_test)`.
    """
    dirname = 'cifar-10-batches-py'
    origin = 'http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz'
    path = get_file(dirname, origin=origin, untar=True)

    num_train_samples = 50000

    x_train = np.zeros((num_train_samples, 3, 32, 32), dtype='uint8')
    y_train = np.zeros((num_train_samples,), dtype='uint8')

    for i in range(1, 6):
        fpath = os.path.join(path, 'data_batch_' + str(i))
        data, labels = load_batch(fpath)
        x_train[(i - 1) * 10000: i * 10000, :, :, :] = data
        y_train[(i - 1) * 10000: i * 10000] = labels

    fpath = os.path.join(path, 'test_batch')
    x_test, y_test = load_batch(fpath)

    y_train = np.reshape(y_train, (len(y_train), 1))
    y_test = np.reshape(y_test, (len(y_test), 1))

    if transpose:
        x_train = x_train.transpose(0, 2, 3, 1)
        x_test = x_test.transpose(0, 2, 3, 1)
    return (x_train, y_train), (x_test, y_test)

# %% [markdown]
# ## Download files
#
# This may take 1 or 2 mins for the first time.

# %%
######################################################################
# Download CIFAR datasets and other related files
######################################################################
colours_fpath = get_file(fname='colours', 
                         origin='http://www.cs.toronto.edu/~jba/kmeans_colour_a2.tar.gz', 
                         untar=True)
m = load_cifar10()
# Out:
# Downloading data from http://www.cs.toronto.edu/~jba/kmeans_colour_a2.tar.gz
# Extracting file.
# Downloading data from http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Extracting file.

# %% [markdown]
# # Code for training and CNN models

# %% [markdown]
# ## Data preprocessing

# %%
"""
Colourization of CIFAR-10 Horses via classification.
"""
from __future__ import print_function
import argparse
import math
import numpy as np
import numpy.random as npr
import scipy.misc
import time
import torch 
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib
import matplotlib.pyplot as plt 


#from load_data import load_cifar10

HORSE_CATEGORY = 7

######################################################################
# Data related code
######################################################################
def get_rgb_cat(xs, colours):
    """
    Get colour categories given RGB values. This function doesn't
    actually do the work, instead it splits the work into smaller
    chunks that can fit into memory, and calls helper function
    _get_rgb_cat

    Args:
      xs: float numpy array of RGB images in [B, C, H, W] format
      colours: numpy array of colour categories and their RGB values
    Returns:
      result: int numpy array of shape [B, 1, H, W]
    """
    if np.shape(xs)[0] < 100:
        return _get_rgb_cat(xs)
    batch_size = 100
    nexts = []
    for i in range(0, np.shape(xs)[0], batch_size):
        next = _get_rgb_cat(xs[i:i+batch_size,:,:,:], colours)
        nexts.append(next)
    result = np.concatenate(nexts, axis=0)
    return result

def _get_rgb_cat(xs, colours):
    """
    Get colour categories given RGB values. This is done by choosing
    the colour in `colours` that is the closest (in RGB space) to
    each point in the image `xs`. This function is a little memory
    intensive, and so the size of `xs` should not be too large.

    Args:
      xs: float numpy array of RGB images in [B, C, H, W] format
      colours: numpy array of colour categories and their RGB values
    Returns:
      result: int numpy array of shape [B, 1, H, W]
    """
    num_colours = np.shape(colours)[0]
    xs = np.expand_dims(xs, 0)
    cs = np.reshape(colours, [num_colours,1,3,1,1])
    dists = np.linalg.norm(xs-cs, axis=2) # 2 = colour axis
    cat = np.argmin(dists, axis=0)
    cat = np.expand_dims(cat, axis=1)
    return cat

def get_cat_rgb(cats, colours):
    """
    Get RGB colours given the colour categories

    Args:
      cats: integer numpy array of colour categories
      colours: numpy array of colour categories and their RGB values
    Returns:
      numpy tensor of RGB colours
    """
    return colours[cats]

def process(xs, ys, max_pixel=256.0, downsize_input=False):
    """
    Pre-process CIFAR10 images by taking only the horse category,
    shuffling, and have colour values be bound between 0 and 1

    Args:
      xs: the colour RGB pixel values
      ys: the category labels
      max_pixel: maximum pixel value in the original data
    Returns:
      xs: value normalized and shuffled colour images
      grey: greyscale images, also normalized so values are between 0 and 1
    """
    print(xs.shape)
    xs = xs / max_pixel
    xs = xs[np.where(ys == HORSE_CATEGORY)[0], :, :, :]
    npr.shuffle(xs)
    
    grey = np.mean(xs, axis=1, keepdims=True)

    if downsize_input:
      downsize_module = nn.Sequential(nn.AvgPool2d(2),
                               nn.AvgPool2d(2), 
                               nn.Upsample(scale_factor=2), 
                               nn.Upsample(scale_factor=2))
      xs_downsized = downsize_module.forward(torch.from_numpy(xs).float())
      xs_downsized = xs_downsized.data.numpy()
      print(xs_downsized.shape)
      return (xs, xs_downsized)
    else:
      return (xs, grey)


def get_batch(x, y, batch_size):
    '''
    Generated that yields batches of data

    Args:
      x: input values
      y: output values
      batch_size: size of each batch
    Yields:
      batch_x: a batch of inputs of size at most batch_size
      batch_y: a batch of outputs of size at most batch_size
    '''
    N = np.shape(x)[0]
    assert N == np.shape(y)[0]
    for i in range(0, N, batch_size):
        batch_x = x[i:i+batch_size, :,:,:]
        batch_y = y[i:i+batch_size, :,:,:]
        yield (batch_x, batch_y)

######################################################################
# Torch Helper
######################################################################

def get_torch_vars(xs, ys, gpu=False):
    """
    Helper function to convert numpy arrays to pytorch tensors.
    If GPU is used, move the tensors to GPU.

    Args:
      xs (float numpy tenosor): greyscale input
      ys (int numpy tenosor): categorical labels 
      gpu (bool): whether to move pytorch tensor to GPU
    Returns:
      Variable(xs), Variable(ys)
    """
    xs = torch.from_numpy(xs).float()
    ys = torch.from_numpy(ys).long()
    if gpu:
        xs = xs.cuda()
        ys = ys.cuda()
    return Variable(xs), Variable(ys)

def compute_loss(criterion, outputs, labels, batch_size, num_colours):
    """
    Helper function to compute the loss. Since this is a pixelwise
    prediction task we need to reshape the output and ground truth
    tensors into a 2D tensor before passing it in to the loss criteron.

    Args:
      criterion: pytorch loss criterion
      outputs (pytorch tensor): predicted labels from the model
      labels (pytorch tensor): ground truth labels
      batch_size (int): batch size used for training
      num_colours (int): number of colour categories
    Returns:
      pytorch tensor for loss
    """

    loss_out = outputs.transpose(1,3) \
                      .contiguous() \
                      .view([batch_size*32*32, num_colours])
    loss_lab = labels.transpose(1,3) \
                      .contiguous() \
                      .view([batch_size*32*32])
    return criterion(loss_out, loss_lab)

def run_validation_step(cnn, criterion, test_grey, test_rgb_cat, batch_size,
                        colours, plotpath=None, visualize=True, downsize_input=False):
    correct = 0.0
    total = 0.0
    losses = []
    num_colours = np.shape(colours)[0]
    for i, (xs, ys) in enumerate(get_batch(test_grey,
                                           test_rgb_cat,
                                           batch_size)):
        images, labels = get_torch_vars(xs, ys, args.gpu)
        outputs = cnn(images)

        val_loss = compute_loss(criterion,
                                outputs,
                                labels,
                                batch_size=args.batch_size,
                                num_colours=num_colours)
        losses.append(val_loss.data.item())

        _, predicted = torch.max(outputs.data, 1, keepdim=True)
        total += labels.size(0) * 32 * 32
        correct += (predicted == labels.data).sum()

    if plotpath: # only plot if a path is provided
        plot(xs, ys, predicted.cpu().numpy(), colours, 
             plotpath, visualize=visualize, compare_bilinear=downsize_input)

    val_loss = np.mean(losses)
    val_acc = 100 * correct / total
    return val_loss, val_acc

# %% [markdown]
# ## Visualization

# %%
def plot(input, gtlabel, output, colours, path, visualize, compare_bilinear=False):
    """
    Generate png plots of input, ground truth, and outputs

    Args:
      input: the greyscale input to the colourization CNN
      gtlabel: the grouth truth categories for each pixel
      output: the predicted categories for each pixel
      colours: numpy array of colour categories and their RGB values
      path: output path
      visualize: display the figures inline or save the figures in path
    """
    grey = np.transpose(input[:10,:,:,:], [0,2,3,1])
    gtcolor = get_cat_rgb(gtlabel[:10,0,:,:], colours)
    predcolor = get_cat_rgb(output[:10,0,:,:], colours)

    img_stack = [
      np.hstack(np.tile(grey, [1,1,1,3])),
      np.hstack(gtcolor),
      np.hstack(predcolor)]
    
    if compare_bilinear:
      downsize_module = nn.Sequential(nn.AvgPool2d(2),
                                 nn.AvgPool2d(2), 
                                 nn.Upsample(scale_factor=2, mode='bilinear'), 
                                 nn.Upsample(scale_factor=2, mode='bilinear'))
      gt_input = np.transpose(gtcolor, [0, 3, 1, 2,])
      color_bilinear = downsize_module.forward(torch.from_numpy(gt_input).float())
      color_bilinear = np.transpose(color_bilinear.data.numpy(), [0, 2, 3, 1])
      img_stack = [
        np.hstack(np.transpose(input[:10,:,:,:], [0,2,3,1])),
        np.hstack(gtcolor),
        np.hstack(predcolor),
        np.hstack(color_bilinear)]
    img = np.vstack(img_stack)
    
    plt.grid('off')
    plt.imshow(img, vmin=0., vmax=1.)
    if visualize:
      plt.show()
    else:
      plt.savefig(path)

def toimage(img, cmin, cmax):
    return Image.fromarray((img.clip(cmin, cmax)*255).astype(np.uint8))
  
def plot_activation(args, cnn):
    # LOAD THE COLOURS CATEGORIES
    colours = np.load(args.colours,allow_pickle=True,encoding='latin1')[0]
    num_colours = np.shape(colours)[0]
    
    (x_train, y_train), (x_test, y_test) = load_cifar10()
    test_rgb, test_grey = process(x_test, y_test, downsize_input = args.downsize_input)
    test_rgb_cat = get_rgb_cat(test_rgb, colours)
    
    # Take the idnex of the test image
    id = args.index
    outdir = "outputs/" + args.experiment_name + '/act' + str(id)
    if not os.path.exists(outdir):
      os.makedirs(outdir)
    images, labels = get_torch_vars(np.expand_dims(test_grey[id], 0),
                                    np.expand_dims(test_rgb_cat[id], 0))
    cnn.cpu()
    outputs = cnn(images)
    _, predicted = torch.max(outputs.data, 1, keepdim=True)
    predcolor = get_cat_rgb(predicted.cpu().numpy()[0,0,:,:], colours)
    img = predcolor
    toimage(predcolor, cmin=0, cmax=1) \
            .save(os.path.join(outdir, "output_%d.png" % id))

    if not args.downsize_input:
      img = np.tile(np.transpose(test_grey[id], [1,2,0]), [1,1,3])
    else:
      img = np.transpose(test_grey[id], [1,2,0])
    toimage(img, cmin=0, cmax=1) \
            .save(os.path.join(outdir, "input_%d.png" % id))

    img = np.transpose(test_rgb[id], [1,2,0])
    toimage(img, cmin=0, cmax=1) \
            .save(os.path.join(outdir, "input_%d_gt.png" % id))

    
    def add_border(img):
        return np.pad(img, 1, "constant", constant_values=1.0)

    def draw_activations(path, activation, imgwidth=4):
        #print("for conternt ",activation.shape[0] // imgwidth)
        img = np.vstack([
            np.hstack([
                add_border(filter) for filter in
                activation[i*imgwidth:(i+1)*imgwidth,:,:]])
            for i in range(activation.shape[0] // imgwidth)])
        imageio.imwrite(path, img)

    for i, tensor in enumerate([cnn.out1, cnn.out2, cnn.out3, cnn.out4, cnn.out5]):
        #print(i)
        draw_activations(
            os.path.join(outdir, "conv%d_out_%d.png" % (i+1, id)),
            tensor.data.cpu().numpy()[0])
        #print("Yo")
    print("visualization results are saved to %s"%outdir)

# %% [markdown]
# ## Training

# %%
class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self

def train(args, cnn=None):
    # Set the maximum number of threads to prevent crash in Teaching Labs
    torch.set_num_threads(5)
    # Numpy random seed
    npr.seed(args.seed)
    
    # Save directory
    save_dir = "outputs/" + args.experiment_name

    # LOAD THE COLOURS CATEGORIES
    colours = np.load(args.colours,allow_pickle=True,encoding='latin1')[0]
    num_colours = np.shape(colours)[0]
    # INPUT CHANNEL
    num_in_channels = 1 if not args.downsize_input else 3
    # LOAD THE MODEL
    if cnn is None:
      if args.model == "CNN":
          cnn = CNN(args.kernel, args.num_filters, num_colours, num_in_channels)
      elif args.model == "UNet":
          cnn = UNet(args.kernel, args.num_filters, num_colours, num_in_channels)

    # LOSS FUNCTION
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(cnn.parameters(), lr=args.learn_rate)

    # DATA
    print("Loading data...")
    (x_train, y_train), (x_test, y_test) = load_cifar10()

    print("Transforming data...")
    train_rgb, train_grey = process(x_train, y_train, downsize_input = args.downsize_input)
    train_rgb_cat = get_rgb_cat(train_rgb, colours)
    test_rgb, test_grey = process(x_test, y_test, downsize_input = args.downsize_input)
    test_rgb_cat = get_rgb_cat(test_rgb, colours)

    # Create the outputs folder if not created already
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    print("Beginning training ...")
    if args.gpu: cnn.cuda()
    start = time.time()

    train_losses = []
    valid_losses = []
    valid_accs = []
    for epoch in range(args.epochs):
        # Train the Model
        cnn.train() # Change model to 'train' mode
        losses = []
        for i, (xs, ys) in enumerate(get_batch(train_grey,
                                               train_rgb_cat,
                                               args.batch_size)):
            images, labels = get_torch_vars(xs, ys, args.gpu)
            # Forward + Backward + Optimize
            optimizer.zero_grad()
            outputs = cnn(images)

            loss = compute_loss(criterion,
                                outputs,
                                labels,
                                batch_size=args.batch_size,
                                num_colours=num_colours)
            loss.backward()
            optimizer.step()
            losses.append(loss.data.item())

        # plot training images
        if args.plot:
            _, predicted = torch.max(outputs.data, 1, keepdim=True)
            plot(xs, ys, predicted.cpu().numpy(), colours,
                 save_dir+'/train_%d.png' % epoch, 
                 args.visualize, 
                 args.downsize_input)

        # plot training images
        avg_loss = np.mean(losses)
        train_losses.append(avg_loss)
        time_elapsed = time.time() - start
        print('Epoch [%d/%d], Loss: %.4f, Time (s): %d' % (
            epoch+1, args.epochs, avg_loss, time_elapsed))

        # Evaluate the model
        cnn.eval()  # Change model to 'eval' mode (BN uses moving mean/var).
        val_loss, val_acc = run_validation_step(cnn,
                                                criterion,
                                                test_grey,
                                                test_rgb_cat,
                                                args.batch_size,
                                                colours,
                                                save_dir+'/test_%d.png' % epoch,
                                                args.visualize,
                                                args.downsize_input)

        time_elapsed = time.time() - start
        valid_losses.append(val_loss)
        valid_accs.append(val_acc)
        print('Epoch [%d/%d], Val Loss: %.4f, Val Acc: %.1f%%, Time(s): %d' % (
            epoch+1, args.epochs, val_loss, val_acc, time_elapsed))
    
    # Plot training curve
    plt.figure()
    plt.plot(train_losses, "ro-", label="Train")
    plt.plot(valid_losses, "go-", label="Validation")
    plt.legend()
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.savefig(save_dir+"/training_curve.png")

    if args.checkpoint:
        print('Saving model...')
        torch.save(cnn.state_dict(), args.checkpoint)
    
    return cnn

# %% [markdown]
# ## Convolutional neural networks (your code goes here)

# %%
######################################################################
# MODELS
######################################################################

class MyConv2d(nn.Module):
    """
    Our simplified implemented of nn.Conv2d module for 2D convolution
    """
    def __init__(self, in_channels, out_channels, kernel_size, padding=None):
        super(MyConv2d, self).__init__()

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        if padding is None:
            self.padding = kernel_size // 2
        else:
            self.padding = padding
        self.weight = nn.parameter.Parameter(torch.Tensor(
            out_channels, in_channels, kernel_size, kernel_size))
        self.bias = nn.parameter.Parameter(torch.Tensor(out_channels))
        self.reset_parameters()

    def reset_parameters(self):
        n = self.in_channels * self.kernel_size * self.kernel_size
        stdv = 1. / math.sqrt(n)
        self.weight.data.uniform_(-stdv, stdv)
        self.bias.data.uniform_(-stdv, stdv)

    def forward(self, input):
        return F.conv2d(input, self.weight, self.bias, padding=self.padding)


class CNN(nn.Module):
    def __init__(self, kernel, num_filters, num_colours, num_in_channels):
        super(CNN, self).__init__()
        padding = kernel // 2

        ############### YOUR CODE GOES HERE ###############
        #self.downconv1 = ...
        self.downconv1 = nn.Sequential(
            MyConv2d(num_in_channels, num_filters, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters),
            nn.ReLU(),
            nn.MaxPool2d(2),)
        self.downconv2 = nn.Sequential(
            MyConv2d(num_filters, num_filters*2, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters*2),
            nn.ReLU(),
            nn.MaxPool2d(2),)

        self.rfconv = nn.Sequential(
            nn.Conv2d(num_filters*2, num_filters*2, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters*2),
            nn.ReLU())

        self.upconv1 = nn.Sequential(
            MyConv2d(num_filters*2, num_filters, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),)
        self.upconv2 = nn.Sequential(
            MyConv2d(num_filters, num_colours, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_colours),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),)
        self.finalconv = MyConv2d(num_colours, num_colours, kernel_size=kernel)
        ###################################################

    def forward(self, x):
        self.out1 = self.downconv1(x)
        self.out2 = self.downconv2(self.out1)
        self.out3 = self.rfconv(self.out2)
        self.out4 = self.upconv1(self.out3)
        self.out5 = self.upconv2(self.out4)
        self.out_final = self.finalconv(self.out5)
        # print(self.out_final.shape)
        return self.out_final

class UNet(nn.Module):
    def __init__(self, kernel, num_filters, num_colours, num_in_channels):
        super(UNet, self).__init__()
        padding = kernel // 2
        ############### YOUR CODE GOES HERE ############### 
        self.downconv1 = nn.Sequential(
            nn.Conv2d(num_in_channels, num_filters, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters),
            nn.ReLU(),
            nn.MaxPool2d(2),)
        self.downconv2 = nn.Sequential(
            nn.Conv2d(num_filters, num_filters*2, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters*2),
            nn.ReLU(),
            nn.MaxPool2d(2),)

        self.rfconv = nn.Sequential(
            nn.Conv2d(num_filters*2, num_filters*2, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters*2),
            nn.ReLU())

        self.upconv1 = nn.Sequential(
            nn.Conv2d(128, num_filters, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),)
        self.upconv2 = nn.Sequential(
            nn.Conv2d(64, num_colours, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_colours),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),)
        self.finalconv = MyConv2d(num_colours, num_colours, kernel_size=kernel)
        ###################################################

    def forward(self, x):
        ############### YOUR CODE GOES HERE ###############
        self.out1 = self.downconv1(x)
        # print(" 1 ",self.out1.shape)
        self.out2 = self.downconv2(self.out1)
        # print("2 ",self.out2.shape)
        self.out3 = self.rfconv(self.out2)
        # print("3 ",self.out3.shape)
        x1 = self.out2
        y1 = self.out3
        z1 = torch.cat([x1,y1],dim=1)
        # print("x1+y1 ",z1.shape)
        self.out4 = self.upconv1(z1)
        # print("4 ",self.out4.shape)
        
        x2 = self.out1
        y2 = self.out4
        z2 = torch.cat([x2,y2],dim=1)
        #print("x2+y2 ",z2.shape)
        
        #print("4 ",self.out4.shape)
        #y = self.out2
        self.out5 = self.upconv2(z2)
        # print("5 ",self.out5.shape)
        #self.out5 = torch.cat([x, y], dim=1)
        #self.out_final = torch.cat([self.finalconv(self.out5), self.out1], dim=1)
        #print("out 5",self.out5.shape)
        self.out_final = self.finalconv(self.out5)
        # print("final ",self.out_final.shape)
        return self.out_final
        ###################################################

# %% [markdown]
# # CIFAR-10 colorization

# %% [markdown]
# ## Main training loop for CNN

# %%
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'model':"CNN", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':100, 
              'epochs':25, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'colourization_cnn',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
cnn = train(args)
# Out:
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Transforming data...
# (50000, 3, 32, 32)
# (10000, 3, 32, 32)
# Beginning training ...
# Epoch [1/25], Loss: 2.4481, Time (s): 1
# Epoch [1/25], Val Loss: 2.1091, Val Acc: 28.8%, Time(s): 2
# Epoch [2/25], Loss: 1.9982, Time (s): 3
# Epoch [2/25], Val Loss: 1.9037, Val Acc: 33.4%, Time(s): 4
# Epoch [3/25], Loss: 1.8776, Time (s): 5
# Epoch [3/25], Val Loss: 1.8174, Val Acc: 35.4%, Time(s): 6
# Epoch [4/25], Loss: 1.8129, Time (s): 7
# Epoch [4/25], Val Loss: 1.7651, Val Acc: 36.8%, Time(s): 8
# Epoch [5/25], Loss: 1.7704, Time (s): 10
# Epoch [5/25], Val Loss: 1.7285, Val Acc: 37.7%, Time(s): 10
# Epoch [6/25], Loss: 1.7392, Time (s): 12
# Epoch [6/25], Val Loss: 1.7016, Val Acc: 38.4%, Time(s): 12
# Epoch [7/25], Loss: 1.7146, Time (s): 14
# Epoch [7/25], Val Loss: 1.6817, Val Acc: 38.8%, Time(s): 14
# Epoch [8/25], Loss: 1.6946, Time (s): 16
# Epoch [8/25], Val Loss: 1.6656, Val Acc: 39.2%, Time(s): 16
# Epoch [9/25], Loss: 1.6778, Time (s): 18
# Epoch [9/25], Val Loss: 1.6541, Val Acc: 39.5%, Time(s): 18
# Epoch [10/25], Loss: 1.6636, Time (s): 20
# Epoch [10/25], Val Loss: 1.6422, Val Acc: 39.7%, Time(s): 21
# Epoch [11/25], Loss: 1.6512, Time (s): 22
# Epoch [11/25], Val Loss: 1.6356, Val Acc: 39.9%, Time(s): 23
# Epoch [12/25], Loss: 1.6408, Time (s): 25
# Epoch [12/25], Val Loss: 1.6267, Val Acc: 40.1%, Time(s): 25
# Epoch [13/25], Loss: 1.6317, Time (s): 27
# Epoch [13/25], Val Loss: 1.6214, Val Acc: 40.2%, Time(s): 27
# Epoch [14/25], Loss: 1.6238, Time (s): 29
# Epoch [14/25], Val Loss: 1.6167, Val Acc: 40.3%, Time(s): 30
# Epoch [15/25], Loss: 1.6164, Time (s): 32
# Epoch [15/25], Val Loss: 1.6138, Val Acc: 40.3%, Time(s): 32
# Epoch [16/25], Loss: 1.6094, Time (s): 34
# Epoch [16/25], Val Loss: 1.6124, Val Acc: 40.4%, Time(s): 34
# Epoch [17/25], Loss: 1.6024, Time (s): 36
# Epoch [17/25], Val Loss: 1.6049, Val Acc: 40.6%, Time(s): 37
# Epoch [18/25], Loss: 1.5952, Time (s): 39
# Epoch [18/25], Val Loss: 1.5972, Val Acc: 40.9%, Time(s): 39
# Epoch [19/25], Loss: 1.5886, Time (s): 41
# Epoch [19/25], Val Loss: 1.5921, Val Acc: 41.1%, Time(s): 42
# Epoch [20/25], Loss: 1.5821, Time (s): 44
# Epoch [20/25], Val Loss: 1.5860, Val Acc: 41.2%, Time(s): 44
# Epoch [21/25], Loss: 1.5764, Time (s): 46
# Epoch [21/25], Val Loss: 1.5819, Val Acc: 41.4%, Time(s): 47
# Epoch [22/25], Loss: 1.5710, Time (s): 49
# Epoch [22/25], Val Loss: 1.5823, Val Acc: 41.3%, Time(s): 49
# Epoch [23/25], Loss: 1.5661, Time (s): 51
# Epoch [23/25], Val Loss: 1.5798, Val Acc: 41.3%, Time(s): 52
# Epoch [24/25], Loss: 1.5613, Time (s): 54
# Epoch [24/25], Val Loss: 1.5787, Val Acc: 41.4%, Time(s): 54
# Epoch [25/25], Loss: 1.5570, Time (s): 56
# Epoch [25/25], Val Loss: 1.5761, Val Acc: 41.5%, Time(s): 57

# %% [markdown]
# ## Main training loop for UNet

# %%
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'model':"UNet", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':100, 
              'epochs':25, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'colourization_unet',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
unet_cnn = train(args)
# Out:
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Transforming data...
# Beginning training ...
# Epoch [1/25], Loss: 2.3493, Time (s): 1
# Epoch [1/25], Val Loss: 2.0387, Val Acc: 30.9%, Time(s): 2
# Epoch [2/25], Loss: 1.8642, Time (s): 4
# Epoch [2/25], Val Loss: 1.7627, Val Acc: 37.3%, Time(s): 4
# Epoch [3/25], Loss: 1.7226, Time (s): 6
# Epoch [3/25], Val Loss: 1.6563, Val Acc: 39.7%, Time(s): 6
# Epoch [4/25], Loss: 1.6495, Time (s): 8
# Epoch [4/25], Val Loss: 1.6009, Val Acc: 41.1%, Time(s): 8
# Epoch [5/25], Loss: 1.6003, Time (s): 10
# Epoch [5/25], Val Loss: 1.5695, Val Acc: 41.7%, Time(s): 10
# Epoch [6/25], Loss: 1.5631, Time (s): 12
# Epoch [6/25], Val Loss: 1.5401, Val Acc: 42.4%, Time(s): 12
# Epoch [7/25], Loss: 1.5322, Time (s): 14
# Epoch [7/25], Val Loss: 1.5081, Val Acc: 43.5%, Time(s): 15
# Epoch [8/25], Loss: 1.5041, Time (s): 16
# Epoch [8/25], Val Loss: 1.4817, Val Acc: 44.5%, Time(s): 17
# Epoch [9/25], Loss: 1.4795, Time (s): 19
# Epoch [9/25], Val Loss: 1.4658, Val Acc: 44.9%, Time(s): 19
# Epoch [10/25], Loss: 1.4583, Time (s): 21
# Epoch [10/25], Val Loss: 1.4595, Val Acc: 45.0%, Time(s): 21
# Epoch [11/25], Loss: 1.4399, Time (s): 23
# Epoch [11/25], Val Loss: 1.4523, Val Acc: 45.1%, Time(s): 24
# Epoch [12/25], Loss: 1.4227, Time (s): 26
# Epoch [12/25], Val Loss: 1.4378, Val Acc: 45.5%, Time(s): 26
# Epoch [13/25], Loss: 1.4070, Time (s): 28
# Epoch [13/25], Val Loss: 1.4138, Val Acc: 46.4%, Time(s): 28
# Epoch [14/25], Loss: 1.3904, Time (s): 30
# Epoch [14/25], Val Loss: 1.3997, Val Acc: 47.0%, Time(s): 31
# Epoch [15/25], Loss: 1.3751, Time (s): 33
# Epoch [15/25], Val Loss: 1.4000, Val Acc: 46.9%, Time(s): 33
# Epoch [16/25], Loss: 1.3610, Time (s): 35
# Epoch [16/25], Val Loss: 1.3868, Val Acc: 47.4%, Time(s): 36
# Epoch [17/25], Loss: 1.3481, Time (s): 38
# Epoch [17/25], Val Loss: 1.3789, Val Acc: 47.7%, Time(s): 38
# Epoch [18/25], Loss: 1.3356, Time (s): 40
# Epoch [18/25], Val Loss: 1.3653, Val Acc: 48.1%, Time(s): 40
# Epoch [19/25], Loss: 1.3234, Time (s): 43
# Epoch [19/25], Val Loss: 1.3566, Val Acc: 48.4%, Time(s): 43
# Epoch [20/25], Loss: 1.3114, Time (s): 45
# Epoch [20/25], Val Loss: 1.3614, Val Acc: 48.2%, Time(s): 46
# Epoch [21/25], Loss: 1.3007, Time (s): 48
# Epoch [21/25], Val Loss: 1.3563, Val Acc: 48.4%, Time(s): 48
# Epoch [22/25], Loss: 1.2901, Time (s): 50
# Epoch [22/25], Val Loss: 1.3523, Val Acc: 48.4%, Time(s): 51
# Epoch [23/25], Loss: 1.2801, Time (s): 53
# Epoch [23/25], Val Loss: 1.3489, Val Acc: 48.6%, Time(s): 53
# Epoch [24/25], Loss: 1.2700, Time (s): 55
# Epoch [24/25], Val Loss: 1.3442, Val Acc: 49.0%, Time(s): 56
# Epoch [25/25], Loss: 1.2606, Time (s): 58
# Epoch [25/25], Val Loss: 1.3347, Val Acc: 49.4%, Time(s): 59

# %% [markdown]
# # CIFAR-10 super-resolution

# %% [markdown]
# ## Main training loop

# %%
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'model':"CNN", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':100, 
              'epochs':25, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'super_res_unet',
              'visualize': False,
              'downsize_input':True,
}
args.update(args_dict)
sr_cnn = train(args)
# Out:
# Loading data...
# Transforming data...
# (50000, 3, 32, 32)
# (5000, 3, 32, 32)
# (10000, 3, 32, 32)
# (1000, 3, 32, 32)
# Beginning training ...
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2494: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# Epoch [1/25], Loss: 2.2644, Time (s): 1
# Epoch [1/25], Val Loss: 1.8635, Val Acc: 37.6%, Time(s): 2
# Epoch [2/25], Loss: 1.6993, Time (s): 3
# Epoch [2/25], Val Loss: 1.6740, Val Acc: 41.2%, Time(s): 4
# Epoch [3/25], Loss: 1.6117, Time (s): 6
# Epoch [3/25], Val Loss: 1.5841, Val Acc: 44.0%, Time(s): 6
# Epoch [4/25], Loss: 1.5768, Time (s): 8
# Epoch [4/25], Val Loss: 1.5617, Val Acc: 44.5%, Time(s): 8
# Epoch [5/25], Loss: 1.5573, Time (s): 10
# Epoch [5/25], Val Loss: 1.5458, Val Acc: 44.9%, Time(s): 10
# Epoch [6/25], Loss: 1.5448, Time (s): 12
# Epoch [6/25], Val Loss: 1.5401, Val Acc: 45.1%, Time(s): 12
# Epoch [7/25], Loss: 1.5367, Time (s): 14
# Epoch [7/25], Val Loss: 1.5277, Val Acc: 45.4%, Time(s): 14
# Epoch [8/25], Loss: 1.5296, Time (s): 16
# Epoch [8/25], Val Loss: 1.5252, Val Acc: 45.4%, Time(s): 17
# Epoch [9/25], Loss: 1.5226, Time (s): 19
# Epoch [9/25], Val Loss: 1.5150, Val Acc: 45.7%, Time(s): 19
# Epoch [10/25], Loss: 1.5169, Time (s): 21
# Epoch [10/25], Val Loss: 1.5096, Val Acc: 45.9%, Time(s): 21
# Epoch [11/25], Loss: 1.5113, Time (s): 23
# Epoch [11/25], Val Loss: 1.5056, Val Acc: 46.0%, Time(s): 24
# Epoch [12/25], Loss: 1.5060, Time (s): 26
# Epoch [12/25], Val Loss: 1.5031, Val Acc: 46.1%, Time(s): 26
# Epoch [13/25], Loss: 1.5013, Time (s): 28
# Epoch [13/25], Val Loss: 1.5010, Val Acc: 46.2%, Time(s): 29
# Epoch [14/25], Loss: 1.4971, Time (s): 31
# Epoch [14/25], Val Loss: 1.4978, Val Acc: 46.3%, Time(s): 31
# Epoch [15/25], Loss: 1.4935, Time (s): 33
# Epoch [15/25], Val Loss: 1.4968, Val Acc: 46.4%, Time(s): 33
# Epoch [16/25], Loss: 1.4903, Time (s): 36
# Epoch [16/25], Val Loss: 1.4944, Val Acc: 46.4%, Time(s): 36
# Epoch [17/25], Loss: 1.4873, Time (s): 38
# Epoch [17/25], Val Loss: 1.4931, Val Acc: 46.4%, Time(s): 39
# Epoch [18/25], Loss: 1.4846, Time (s): 41
# Epoch [18/25], Val Loss: 1.4976, Val Acc: 46.3%, Time(s): 41
# Epoch [19/25], Loss: 1.4821, Time (s): 43
# Epoch [19/25], Val Loss: 1.4951, Val Acc: 46.4%, Time(s): 44
# Epoch [20/25], Loss: 1.4799, Time (s): 46
# Epoch [20/25], Val Loss: 1.4942, Val Acc: 46.3%, Time(s): 46
# Epoch [21/25], Loss: 1.4778, Time (s): 49
# Epoch [21/25], Val Loss: 1.4940, Val Acc: 46.3%, Time(s): 49
# Epoch [22/25], Loss: 1.4758, Time (s): 51
# Epoch [22/25], Val Loss: 1.4918, Val Acc: 46.3%, Time(s): 52
# Epoch [23/25], Loss: 1.4740, Time (s): 54
# Epoch [23/25], Val Loss: 1.4918, Val Acc: 46.3%, Time(s): 55
# Epoch [24/25], Loss: 1.4722, Time (s): 57
# Epoch [24/25], Val Loss: 1.4923, Val Acc: 46.2%, Time(s): 57
# Epoch [25/25], Loss: 1.4704, Time (s): 60
# Epoch [25/25], Val Loss: 1.4861, Val Acc: 46.4%, Time(s): 60

# %% [markdown]
# ## **Super Resolution with UNet Architecture**

# %%
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'model':"UNet", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':100, 
              'epochs':25, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'super_res_unet',
              'visualize': False,
              'downsize_input':True,
}
args.update(args_dict)
sr_cnn = train(args)
# Out:
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Transforming data...
# (50000, 3, 32, 32)
# (5000, 3, 32, 32)
# (10000, 3, 32, 32)
# (1000, 3, 32, 32)
# Beginning training ...
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2494: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# Epoch [1/25], Loss: 2.1855, Time (s): 2
# Epoch [1/25], Val Loss: 1.8105, Val Acc: 39.2%, Time(s): 2
# Epoch [2/25], Loss: 1.6691, Time (s): 4
# Epoch [2/25], Val Loss: 1.6129, Val Acc: 43.0%, Time(s): 4
# Epoch [3/25], Loss: 1.5925, Time (s): 6
# Epoch [3/25], Val Loss: 1.5721, Val Acc: 43.9%, Time(s): 6
# Epoch [4/25], Loss: 1.5612, Time (s): 8
# Epoch [4/25], Val Loss: 1.5460, Val Acc: 44.7%, Time(s): 8
# Epoch [5/25], Loss: 1.5422, Time (s): 10
# Epoch [5/25], Val Loss: 1.5290, Val Acc: 45.2%, Time(s): 10
# Epoch [6/25], Loss: 1.5278, Time (s): 12
# Epoch [6/25], Val Loss: 1.5235, Val Acc: 45.4%, Time(s): 13
# Epoch [7/25], Loss: 1.5168, Time (s): 14
# Epoch [7/25], Val Loss: 1.5123, Val Acc: 45.8%, Time(s): 15
# Epoch [8/25], Loss: 1.5081, Time (s): 17
# Epoch [8/25], Val Loss: 1.5026, Val Acc: 46.0%, Time(s): 17
# Epoch [9/25], Loss: 1.5008, Time (s): 19
# Epoch [9/25], Val Loss: 1.4986, Val Acc: 46.2%, Time(s): 19
# Epoch [10/25], Loss: 1.4942, Time (s): 21
# Epoch [10/25], Val Loss: 1.4956, Val Acc: 46.2%, Time(s): 22
# Epoch [11/25], Loss: 1.4883, Time (s): 24
# Epoch [11/25], Val Loss: 1.4927, Val Acc: 46.4%, Time(s): 24
# Epoch [12/25], Loss: 1.4832, Time (s): 26
# Epoch [12/25], Val Loss: 1.4948, Val Acc: 46.4%, Time(s): 27
# Epoch [13/25], Loss: 1.4789, Time (s): 29
# Epoch [13/25], Val Loss: 1.4982, Val Acc: 46.3%, Time(s): 29
# Epoch [14/25], Loss: 1.4756, Time (s): 31
# Epoch [14/25], Val Loss: 1.5015, Val Acc: 46.2%, Time(s): 32
# Epoch [15/25], Loss: 1.4727, Time (s): 34
# Epoch [15/25], Val Loss: 1.4980, Val Acc: 46.3%, Time(s): 34
# Epoch [16/25], Loss: 1.4699, Time (s): 36
# Epoch [16/25], Val Loss: 1.4823, Val Acc: 46.5%, Time(s): 37
# Epoch [17/25], Loss: 1.4666, Time (s): 39
# Epoch [17/25], Val Loss: 1.4775, Val Acc: 46.7%, Time(s): 39
# Epoch [18/25], Loss: 1.4633, Time (s): 41
# Epoch [18/25], Val Loss: 1.4791, Val Acc: 46.4%, Time(s): 42
# Epoch [19/25], Loss: 1.4603, Time (s): 44
# Epoch [19/25], Val Loss: 1.4766, Val Acc: 46.5%, Time(s): 44
# Epoch [20/25], Loss: 1.4578, Time (s): 47
# Epoch [20/25], Val Loss: 1.4769, Val Acc: 46.5%, Time(s): 47
# Epoch [21/25], Loss: 1.4549, Time (s): 49
# Epoch [21/25], Val Loss: 1.4742, Val Acc: 46.6%, Time(s): 50
# Epoch [22/25], Loss: 1.4521, Time (s): 52
# Epoch [22/25], Val Loss: 1.4722, Val Acc: 46.7%, Time(s): 53
# Epoch [23/25], Loss: 1.4494, Time (s): 55
# Epoch [23/25], Val Loss: 1.4714, Val Acc: 46.7%, Time(s): 55
# Epoch [24/25], Loss: 1.4472, Time (s): 58
# Epoch [24/25], Val Loss: 1.4701, Val Acc: 46.7%, Time(s): 58
# Epoch [25/25], Loss: 1.4453, Time (s): 60
# Epoch [25/25], Val Loss: 1.4706, Val Acc: 46.7%, Time(s): 61

# %% [markdown]
# # Visualization

# %% [markdown]
# You will run the following code to generate visualization results. The generated images are saved in the file system of this Colab notebook. You can find them by selecting  the "Files" tab on the left side of the screen.
#
# >  **Files**  →   **CS6360** →   **a2**  →   **outputs**

# %% [markdown]
# ## Visualize CNN

# %%
args = AttrDict()
args_dict = {
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'index':0,
              'experiment_name': 'colourization_cnn',
              'downsize_input':False,
}
args.update(args_dict)
plot_activation(args, cnn)
# Out:
# data/cifar-10-batches-py.tar.gz
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 6.714720726013184]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 3.7563393115997314]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 4.253747940063477]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 3.5800631046295166]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 4.761887073516846]. Convert image to uint8 prior to saving to suppress this warning.
# visualization results are saved to outputs/colourization_cnn/act0

# %% [markdown]
# ## Visualize UNet

# %%
args = AttrDict()
args_dict = {
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'index':0,
              'experiment_name': 'colourization_unet',
              'downsize_input':False,
}
args.update(args_dict)
plot_activation(args, unet_cnn)
# Out:
# data/cifar-10-batches-py.tar.gz
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 5.934074878692627]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 2.940286159515381]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 2.8837342262268066]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 2.5247020721435547]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 6.817536354064941]. Convert image to uint8 prior to saving to suppress this warning.
# visualization results are saved to outputs/colourization_unet/act0

# %% [markdown]
# ## Visualize super-resolution

# %%
args = AttrDict()
args_dict = {
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'index':0,
              'experiment_name': 'super_res_unet',
              'downsize_input':True,
}
args.update(args_dict)
plot_activation(args, sr_cnn)
# Out:
# data/cifar-10-batches-py.tar.gz
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 5.680283546447754]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 4.215620040893555]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 4.379446983337402]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 3.2954325675964355]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 4.498624801635742]. Convert image to uint8 prior to saving to suppress this warning.
# visualization results are saved to outputs/super_res_unet/act0

# %% [markdown]
# # **With changed learning rate CNN model**

# %%
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'model':"CNN", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.01, 
              'batch_size':100, 
              'epochs':25, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'colourization_cnn',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
cnn = train(args)
# Out:
# Loading data...
# Transforming data...
# (50000, 3, 32, 32)
# (10000, 3, 32, 32)
# Beginning training ...
# Epoch [1/25], Loss: 2.2895, Time (s): 2
# Epoch [1/25], Val Loss: 2.0619, Val Acc: 29.4%, Time(s): 2
# Epoch [2/25], Loss: 1.9437, Time (s): 4
# Epoch [2/25], Val Loss: 1.9591, Val Acc: 31.5%, Time(s): 4
# Epoch [3/25], Loss: 1.8423, Time (s): 6
# Epoch [3/25], Val Loss: 1.9270, Val Acc: 32.2%, Time(s): 6
# Epoch [4/25], Loss: 1.7837, Time (s): 8
# Epoch [4/25], Val Loss: 1.9377, Val Acc: 31.6%, Time(s): 8
# Epoch [5/25], Loss: 1.7399, Time (s): 10
# Epoch [5/25], Val Loss: 1.8879, Val Acc: 33.8%, Time(s): 10
# Epoch [6/25], Loss: 1.7096, Time (s): 12
# Epoch [6/25], Val Loss: 1.8332, Val Acc: 34.1%, Time(s): 12
# Epoch [7/25], Loss: 1.6825, Time (s): 14
# Epoch [7/25], Val Loss: 1.8906, Val Acc: 32.2%, Time(s): 14
# Epoch [8/25], Loss: 1.6597, Time (s): 16
# Epoch [8/25], Val Loss: 1.8136, Val Acc: 34.3%, Time(s): 16
# Epoch [9/25], Loss: 1.6421, Time (s): 18
# Epoch [9/25], Val Loss: 1.7771, Val Acc: 35.3%, Time(s): 19
# Epoch [10/25], Loss: 1.6263, Time (s): 21
# Epoch [10/25], Val Loss: 1.7907, Val Acc: 35.1%, Time(s): 21
# Epoch [11/25], Loss: 1.6094, Time (s): 23
# Epoch [11/25], Val Loss: 1.7437, Val Acc: 36.2%, Time(s): 23
# Epoch [12/25], Loss: 1.6000, Time (s): 25
# Epoch [12/25], Val Loss: 1.7312, Val Acc: 36.8%, Time(s): 25
# Epoch [13/25], Loss: 1.5915, Time (s): 27
# Epoch [13/25], Val Loss: 1.7895, Val Acc: 36.0%, Time(s): 28
# Epoch [14/25], Loss: 1.5846, Time (s): 30
# Epoch [14/25], Val Loss: 1.6686, Val Acc: 38.7%, Time(s): 30
# Epoch [15/25], Loss: 1.5776, Time (s): 32
# Epoch [15/25], Val Loss: 1.6886, Val Acc: 38.1%, Time(s): 32
# Epoch [16/25], Loss: 1.5686, Time (s): 34
# Epoch [16/25], Val Loss: 1.6712, Val Acc: 38.8%, Time(s): 35
# Epoch [17/25], Loss: 1.5606, Time (s): 37
# Epoch [17/25], Val Loss: 1.6758, Val Acc: 38.6%, Time(s): 37
# Epoch [18/25], Loss: 1.5541, Time (s): 39
# Epoch [18/25], Val Loss: 1.6211, Val Acc: 40.0%, Time(s): 40
# Epoch [19/25], Loss: 1.5491, Time (s): 42
# Epoch [19/25], Val Loss: 1.6188, Val Acc: 40.0%, Time(s): 42
# Epoch [20/25], Loss: 1.5435, Time (s): 44
# Epoch [20/25], Val Loss: 1.6912, Val Acc: 38.1%, Time(s): 45
# Epoch [21/25], Loss: 1.5372, Time (s): 47
# Epoch [21/25], Val Loss: 1.6726, Val Acc: 38.5%, Time(s): 47
# Epoch [22/25], Loss: 1.5324, Time (s): 49
# Epoch [22/25], Val Loss: 1.6686, Val Acc: 38.8%, Time(s): 50
# Epoch [23/25], Loss: 1.5289, Time (s): 52
# Epoch [23/25], Val Loss: 1.6811, Val Acc: 38.8%, Time(s): 52
# Epoch [24/25], Loss: 1.5242, Time (s): 55
# Epoch [24/25], Val Loss: 1.7461, Val Acc: 37.5%, Time(s): 55
# Epoch [25/25], Loss: 1.5181, Time (s): 57
# Epoch [25/25], Val Loss: 1.6522, Val Acc: 39.5%, Time(s): 58

# %%
# 200 MiniBatch
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'model':"UNet", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':200, 
              'epochs':25, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'colourization_unet',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
unet_cnn_200_MB = train(args)
# Out:
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Transforming data...
# Beginning training ...
# Epoch [1/25], Loss: 2.5518, Time (s): 1
# Epoch [1/25], Val Loss: 2.6142, Val Acc: 13.3%, Time(s): 2
# Epoch [2/25], Loss: 2.0500, Time (s): 3
# Epoch [2/25], Val Loss: 1.9919, Val Acc: 32.1%, Time(s): 4
# Epoch [3/25], Loss: 1.8712, Time (s): 5
# Epoch [3/25], Val Loss: 1.8256, Val Acc: 35.8%, Time(s): 6
# Epoch [4/25], Loss: 1.7729, Time (s): 7
# Epoch [4/25], Val Loss: 1.7362, Val Acc: 38.2%, Time(s): 8
# Epoch [5/25], Loss: 1.7074, Time (s): 9
# Epoch [5/25], Val Loss: 1.6760, Val Acc: 39.4%, Time(s): 10
# Epoch [6/25], Loss: 1.6602, Time (s): 12
# Epoch [6/25], Val Loss: 1.6347, Val Acc: 40.1%, Time(s): 12
# Epoch [7/25], Loss: 1.6236, Time (s): 14
# Epoch [7/25], Val Loss: 1.6126, Val Acc: 40.3%, Time(s): 14
# Epoch [8/25], Loss: 1.5942, Time (s): 16
# Epoch [8/25], Val Loss: 1.5841, Val Acc: 41.2%, Time(s): 16
# Epoch [9/25], Loss: 1.5679, Time (s): 18
# Epoch [9/25], Val Loss: 1.5606, Val Acc: 42.0%, Time(s): 18
# Epoch [10/25], Loss: 1.5443, Time (s): 20
# Epoch [10/25], Val Loss: 1.5438, Val Acc: 42.6%, Time(s): 20
# Epoch [11/25], Loss: 1.5233, Time (s): 22
# Epoch [11/25], Val Loss: 1.5373, Val Acc: 42.8%, Time(s): 23
# Epoch [12/25], Loss: 1.5047, Time (s): 25
# Epoch [12/25], Val Loss: 1.5225, Val Acc: 43.1%, Time(s): 25
# Epoch [13/25], Loss: 1.4879, Time (s): 27
# Epoch [13/25], Val Loss: 1.5074, Val Acc: 43.6%, Time(s): 27
# Epoch [14/25], Loss: 1.4721, Time (s): 29
# Epoch [14/25], Val Loss: 1.4897, Val Acc: 44.1%, Time(s): 30
# Epoch [15/25], Loss: 1.4572, Time (s): 31
# Epoch [15/25], Val Loss: 1.4707, Val Acc: 44.7%, Time(s): 32
# Epoch [16/25], Loss: 1.4423, Time (s): 34
# Epoch [16/25], Val Loss: 1.4610, Val Acc: 45.0%, Time(s): 34
# Epoch [17/25], Loss: 1.4274, Time (s): 36
# Epoch [17/25], Val Loss: 1.4494, Val Acc: 45.2%, Time(s): 37
# Epoch [18/25], Loss: 1.4138, Time (s): 39
# Epoch [18/25], Val Loss: 1.4412, Val Acc: 45.3%, Time(s): 39
# Epoch [19/25], Loss: 1.4014, Time (s): 41
# Epoch [19/25], Val Loss: 1.4387, Val Acc: 45.3%, Time(s): 42
# Epoch [20/25], Loss: 1.3903, Time (s): 44
# Epoch [20/25], Val Loss: 1.4304, Val Acc: 45.7%, Time(s): 44
# Epoch [21/25], Loss: 1.3795, Time (s): 46
# Epoch [21/25], Val Loss: 1.4285, Val Acc: 45.6%, Time(s): 47
# Epoch [22/25], Loss: 1.3697, Time (s): 49
# Epoch [22/25], Val Loss: 1.4150, Val Acc: 45.9%, Time(s): 49
# Epoch [23/25], Loss: 1.3608, Time (s): 51
# Epoch [23/25], Val Loss: 1.4175, Val Acc: 45.9%, Time(s): 52
# Epoch [24/25], Loss: 1.3528, Time (s): 54
# Epoch [24/25], Val Loss: 1.4209, Val Acc: 46.3%, Time(s): 54
# Epoch [25/25], Loss: 1.3441, Time (s): 56
# Epoch [25/25], Val Loss: 1.4058, Val Acc: 47.0%, Time(s): 57

# %%
# 50 Minibatch
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'model':"UNet", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':50, 
              'epochs':25, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'colourization_unet',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
unet_cnn_50_MB = train(args)
# Out:
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Transforming data...
# Beginning training ...
# Epoch [1/25], Loss: 2.1517, Time (s): 2
# Epoch [1/25], Val Loss: 1.8045, Val Acc: 35.6%, Time(s): 2
# Epoch [2/25], Loss: 1.7461, Time (s): 5
# Epoch [2/25], Val Loss: 1.6472, Val Acc: 40.1%, Time(s): 5
# Epoch [3/25], Loss: 1.6398, Time (s): 7
# Epoch [3/25], Val Loss: 1.5653, Val Acc: 42.3%, Time(s): 7
# Epoch [4/25], Loss: 1.5751, Time (s): 10
# Epoch [4/25], Val Loss: 1.5131, Val Acc: 43.7%, Time(s): 10
# Epoch [5/25], Loss: 1.5269, Time (s): 12
# Epoch [5/25], Val Loss: 1.4771, Val Acc: 44.8%, Time(s): 13
# Epoch [6/25], Loss: 1.4897, Time (s): 15
# Epoch [6/25], Val Loss: 1.4529, Val Acc: 45.4%, Time(s): 15
# Epoch [7/25], Loss: 1.4591, Time (s): 18
# Epoch [7/25], Val Loss: 1.4354, Val Acc: 45.9%, Time(s): 18
# Epoch [8/25], Loss: 1.4336, Time (s): 21
# Epoch [8/25], Val Loss: 1.4166, Val Acc: 46.5%, Time(s): 21
# Epoch [9/25], Loss: 1.4116, Time (s): 23
# Epoch [9/25], Val Loss: 1.4047, Val Acc: 46.7%, Time(s): 24
# Epoch [10/25], Loss: 1.3918, Time (s): 26
# Epoch [10/25], Val Loss: 1.3911, Val Acc: 47.1%, Time(s): 27
# Epoch [11/25], Loss: 1.3742, Time (s): 29
# Epoch [11/25], Val Loss: 1.3817, Val Acc: 47.4%, Time(s): 29
# Epoch [12/25], Loss: 1.3582, Time (s): 32
# Epoch [12/25], Val Loss: 1.3698, Val Acc: 47.7%, Time(s): 32
# Epoch [13/25], Loss: 1.3437, Time (s): 35
# Epoch [13/25], Val Loss: 1.3647, Val Acc: 47.9%, Time(s): 35
# Epoch [14/25], Loss: 1.3302, Time (s): 38
# Epoch [14/25], Val Loss: 1.3598, Val Acc: 48.0%, Time(s): 38
# Epoch [15/25], Loss: 1.3177, Time (s): 41
# Epoch [15/25], Val Loss: 1.3505, Val Acc: 48.4%, Time(s): 41
# Epoch [16/25], Loss: 1.3059, Time (s): 44
# Epoch [16/25], Val Loss: 1.3478, Val Acc: 48.5%, Time(s): 44
# Epoch [17/25], Loss: 1.2947, Time (s): 46
# Epoch [17/25], Val Loss: 1.3456, Val Acc: 48.6%, Time(s): 47
# Epoch [18/25], Loss: 1.2844, Time (s): 50
# Epoch [18/25], Val Loss: 1.3529, Val Acc: 48.4%, Time(s): 50
# Epoch [19/25], Loss: 1.2743, Time (s): 53
# Epoch [19/25], Val Loss: 1.3417, Val Acc: 48.8%, Time(s): 53
# Epoch [20/25], Loss: 1.2645, Time (s): 56
# Epoch [20/25], Val Loss: 1.3376, Val Acc: 49.1%, Time(s): 56
# Epoch [21/25], Loss: 1.2550, Time (s): 59
# Epoch [21/25], Val Loss: 1.3426, Val Acc: 49.0%, Time(s): 59
# Epoch [22/25], Loss: 1.2456, Time (s): 62
# Epoch [22/25], Val Loss: 1.3456, Val Acc: 48.8%, Time(s): 62
# Epoch [23/25], Loss: 1.2368, Time (s): 65
# Epoch [23/25], Val Loss: 1.3355, Val Acc: 49.3%, Time(s): 65
# Epoch [24/25], Loss: 1.2281, Time (s): 68
# Epoch [24/25], Val Loss: 1.3372, Val Acc: 49.5%, Time(s): 69
# Epoch [25/25], Loss: 1.2194, Time (s): 71
# Epoch [25/25], Val Loss: 1.3370, Val Acc: 49.5%, Time(s): 72

# %%
# 10 MiniBatch
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'model':"UNet", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':10, 
              'epochs':25, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'colourization_unet',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
unet_cnn_10_MB = train(args)
# Out:
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Transforming data...
# Beginning training ...
# Epoch [1/25], Loss: 1.9597, Time (s): 5
# Epoch [1/25], Val Loss: 1.6475, Val Acc: 39.6%, Time(s): 6
# Epoch [2/25], Loss: 1.7220, Time (s): 11
# Epoch [2/25], Val Loss: 1.5368, Val Acc: 42.9%, Time(s): 12
# Epoch [3/25], Loss: 1.6412, Time (s): 18
# Epoch [3/25], Val Loss: 1.4808, Val Acc: 44.6%, Time(s): 18
# Epoch [4/25], Loss: 1.5856, Time (s): 24
# Epoch [4/25], Val Loss: 1.4402, Val Acc: 46.0%, Time(s): 24
# Epoch [5/25], Loss: 1.5404, Time (s): 30
# Epoch [5/25], Val Loss: 1.4054, Val Acc: 47.2%, Time(s): 31
# Epoch [6/25], Loss: 1.4981, Time (s): 36
# Epoch [6/25], Val Loss: 1.3909, Val Acc: 47.6%, Time(s): 37
# Epoch [7/25], Loss: 1.4576, Time (s): 43
# Epoch [7/25], Val Loss: 1.3776, Val Acc: 47.9%, Time(s): 43
# Epoch [8/25], Loss: 1.4205, Time (s): 49
# Epoch [8/25], Val Loss: 1.3698, Val Acc: 48.1%, Time(s): 50
# Epoch [9/25], Loss: 1.3890, Time (s): 55
# Epoch [9/25], Val Loss: 1.3582, Val Acc: 48.5%, Time(s): 56
# Epoch [10/25], Loss: 1.3626, Time (s): 62
# Epoch [10/25], Val Loss: 1.3632, Val Acc: 48.2%, Time(s): 62
# Epoch [11/25], Loss: 1.3397, Time (s): 68
# Epoch [11/25], Val Loss: 1.3543, Val Acc: 48.6%, Time(s): 69
# Epoch [12/25], Loss: 1.3192, Time (s): 75
# Epoch [12/25], Val Loss: 1.3564, Val Acc: 48.5%, Time(s): 75
# Epoch [13/25], Loss: 1.3013, Time (s): 81
# Epoch [13/25], Val Loss: 1.3689, Val Acc: 48.2%, Time(s): 82
# Epoch [14/25], Loss: 1.2849, Time (s): 88
# Epoch [14/25], Val Loss: 1.3764, Val Acc: 47.8%, Time(s): 88
# Epoch [15/25], Loss: 1.2704, Time (s): 94
# Epoch [15/25], Val Loss: 1.3668, Val Acc: 48.2%, Time(s): 95
# Epoch [16/25], Loss: 1.2567, Time (s): 101
# Epoch [16/25], Val Loss: 1.3599, Val Acc: 48.5%, Time(s): 101
# Epoch [17/25], Loss: 1.2443, Time (s): 107
# Epoch [17/25], Val Loss: 1.3841, Val Acc: 47.8%, Time(s): 108
# Epoch [18/25], Loss: 1.2323, Time (s): 114
# Epoch [18/25], Val Loss: 1.3517, Val Acc: 49.0%, Time(s): 114
# Epoch [19/25], Loss: 1.2217, Time (s): 120
# Epoch [19/25], Val Loss: 1.3584, Val Acc: 48.8%, Time(s): 121
# Epoch [20/25], Loss: 1.2114, Time (s): 127
# Epoch [20/25], Val Loss: 1.3436, Val Acc: 49.4%, Time(s): 128
# Epoch [21/25], Loss: 1.2013, Time (s): 134
# Epoch [21/25], Val Loss: 1.3349, Val Acc: 49.7%, Time(s): 134
# Epoch [22/25], Loss: 1.1914, Time (s): 140
# Epoch [22/25], Val Loss: 1.3180, Val Acc: 50.3%, Time(s): 141
# Epoch [23/25], Loss: 1.1823, Time (s): 147
# Epoch [23/25], Val Loss: 1.3144, Val Acc: 50.6%, Time(s): 148
# Epoch [24/25], Loss: 1.1733, Time (s): 154
# Epoch [24/25], Val Loss: 1.3146, Val Acc: 50.7%, Time(s): 155
# Epoch [25/25], Loss: 1.1646, Time (s): 161
# Epoch [25/25], Val Loss: 1.3068, Val Acc: 51.1%, Time(s): 161

# %%
# 20 MiniBatch
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'colours':'./data/colours/colour_kmeans24_cat7.npy', 
              'model':"UNet", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':20, 
              'epochs':25, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'colourization_unet',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
unet_cnn_20_MB = train(args)
# Out:
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Transforming data...
# Beginning training ...
# Epoch [1/25], Loss: 1.9966, Time (s): 4
# Epoch [1/25], Val Loss: 1.9058, Val Acc: 33.4%, Time(s): 4
# Epoch [2/25], Loss: 1.7101, Time (s): 8
# Epoch [2/25], Val Loss: 1.7189, Val Acc: 36.9%, Time(s): 8
# Epoch [3/25], Loss: 1.6232, Time (s): 12
# Epoch [3/25], Val Loss: 1.5907, Val Acc: 40.3%, Time(s): 12
# Epoch [4/25], Loss: 1.5661, Time (s): 16
# Epoch [4/25], Val Loss: 1.5042, Val Acc: 43.2%, Time(s): 17
# Epoch [5/25], Loss: 1.5240, Time (s): 21
# Epoch [5/25], Val Loss: 1.4502, Val Acc: 45.3%, Time(s): 21
# Epoch [6/25], Loss: 1.4913, Time (s): 25
# Epoch [6/25], Val Loss: 1.4090, Val Acc: 46.9%, Time(s): 26
# Epoch [7/25], Loss: 1.4645, Time (s): 29
# Epoch [7/25], Val Loss: 1.3832, Val Acc: 47.9%, Time(s): 30
# Epoch [8/25], Loss: 1.4417, Time (s): 34
# Epoch [8/25], Val Loss: 1.3760, Val Acc: 47.9%, Time(s): 34
# Epoch [9/25], Loss: 1.4218, Time (s): 38
# Epoch [9/25], Val Loss: 1.3541, Val Acc: 48.5%, Time(s): 39
# Epoch [10/25], Loss: 1.4038, Time (s): 43
# Epoch [10/25], Val Loss: 1.3535, Val Acc: 48.5%, Time(s): 43
# Epoch [11/25], Loss: 1.3874, Time (s): 47
# Epoch [11/25], Val Loss: 1.3355, Val Acc: 49.0%, Time(s): 48
# Epoch [12/25], Loss: 1.3721, Time (s): 52
# Epoch [12/25], Val Loss: 1.3184, Val Acc: 49.6%, Time(s): 52
# Epoch [13/25], Loss: 1.3573, Time (s): 56
# Epoch [13/25], Val Loss: 1.3206, Val Acc: 49.4%, Time(s): 57
# Epoch [14/25], Loss: 1.3428, Time (s): 61
# Epoch [14/25], Val Loss: 1.3117, Val Acc: 49.7%, Time(s): 62
# Epoch [15/25], Loss: 1.3288, Time (s): 66
# Epoch [15/25], Val Loss: 1.3155, Val Acc: 49.6%, Time(s): 66
# Epoch [16/25], Loss: 1.3152, Time (s): 70
# Epoch [16/25], Val Loss: 1.3088, Val Acc: 49.9%, Time(s): 71
# Epoch [17/25], Loss: 1.3017, Time (s): 75
# Epoch [17/25], Val Loss: 1.3094, Val Acc: 49.8%, Time(s): 76
# Epoch [18/25], Loss: 1.2886, Time (s): 80
# Epoch [18/25], Val Loss: 1.3111, Val Acc: 49.9%, Time(s): 80
# Epoch [19/25], Loss: 1.2764, Time (s): 84
# Epoch [19/25], Val Loss: 1.2962, Val Acc: 50.5%, Time(s): 85
# Epoch [20/25], Loss: 1.2642, Time (s): 89
# Epoch [20/25], Val Loss: 1.2831, Val Acc: 50.9%, Time(s): 90
# Epoch [21/25], Loss: 1.2523, Time (s): 94
# Epoch [21/25], Val Loss: 1.2874, Val Acc: 50.8%, Time(s): 95
# Epoch [22/25], Loss: 1.2409, Time (s): 99
# Epoch [22/25], Val Loss: 1.3005, Val Acc: 50.3%, Time(s): 99
# Epoch [23/25], Loss: 1.2301, Time (s): 104
# Epoch [23/25], Val Loss: 1.2868, Val Acc: 50.8%, Time(s): 104
# Epoch [24/25], Loss: 1.2195, Time (s): 108
# Epoch [24/25], Val Loss: 1.2928, Val Acc: 50.6%, Time(s): 109
# Epoch [25/25], Loss: 1.2089, Time (s): 113
# Epoch [25/25], Val Loss: 1.2902, Val Acc: 50.8%, Time(s): 114

# %%
batch_size = [200,100,50,20,10]
val_loss = [1.4058,1.3347,1.3370,1.2902,1.3068]
train_loss = [1.3441,1.2606,1.2194,1.2089,1.1646]
Val_acc = [46.9,49.4,49.5,50.8,51.1]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(batch_size, val_loss,'bo-') 
plt.xlim(210, 0) 

for x,y in zip(batch_size, val_loss,):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# naming the x axis 
plt.xlabel('Batch Size') 
# naming the y axis 
plt.ylabel('Val Loss') 
  
# giving a title to my graph 
plt.title('Validation loss effect wrt Batch Size') 
  
# function to show the plot 
plt.show()

# %%
plt.plot(batch_size, train_loss,'bo-') 
plt.xlim(210, 0) 

for x,y in zip(batch_size, train_loss,):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# naming the x axis 
plt.xlabel('Batch Size') 
# naming the y axis 
plt.ylabel('Train Loss') 
  
# giving a title to my graph 
plt.title('Train loss effect wrt Batch Size') 
  
# function to show the plot 
plt.show()

# %%
plt.plot(batch_size, Val_acc,'bo-') 
for x,y in zip(batch_size, Val_acc,):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# naming the x axis 
plt.xlabel('Batch Size') 
# naming the y axis 
plt.ylabel('Accuracy') 
  
# giving a title to my graph 
plt.title('Accuracy wrt Batch Size') 
  
# function to show the plot 
plt.show()
